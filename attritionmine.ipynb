# %% [markdown]
# <h2>Import the libraries</h2>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>Load the attrition dataset</h2>

# %%
import pandas as pd


df = pd.read_csv('Attrition_dataset.csv')

# %% [markdown]
# <h2>Understand the columns</h2>

# %%
df.columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %% [markdown]
# <h2>Get the information of each column and note the observation</h2>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
# ...

# %%
df
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %% [markdown]
# <h2>Take a look at top 10 records and understand</h2>

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df.head(10)
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# ...

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# ...

# %%
df.tail(10)
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49643        8188  10/1/2014 0:00    10/22/1993        4/25/2013
# 49644        8214  12/1/2014 0:00      1/6/1994         6/5/2013
# 49645        8223  10/1/2013 0:00     2/11/1994        6/24/2013
# 49646        8226   9/1/2013 0:00     2/16/1994        6/26/2013
# 49647        8231  12/1/2015 0:00      3/1/1994         7/3/2013
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49643          10/25/2014   21                  1     Victoria
# 49644          12/30/2014   20                  1        Haney
# ...

# %% [markdown]
# <h2>Data cleaning</h2>
# <ol><li>check for duplicates (either records or empid(pk) ) and remove them and reset the index</li>
# <li>handle the missing values</li>
# <li>drop the column ('gender_short' )</li>
# <li>handle the invalid dtypes</li>
# </ol>

# %% [markdown]
# <h2>1. Check for duplicates (either records or empid(pk) ) and remove them and reset the index</h2>

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49648    False
# 49649    False
# 49650    False
# 49651    False
# 49652    False
# Length: 49653, dtype: bool

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df['EmployeeID'].duplicated().any()
# Out:
# np.True_

# %%
df
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %%
# df['EmployeeID'] = df['EmployeeID'].drop_duplicates()

# %%
# df

# %%
# df.dropna()

# %% [markdown]
# <h2>2. Handle the missing values</h2>

# %%
df['EmployeeID'] = df['EmployeeID'].drop_duplicates(keep='last')

# %%
df
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0             NaN  12/31/2006 0:00      1/3/1954        8/28/1989
# 1             NaN  12/31/2007 0:00      1/3/1954        8/28/1989
# 2             NaN  12/31/2008 0:00      1/3/1954        8/28/1989
# 3             NaN  12/31/2009 0:00      1/3/1954        8/28/1989
# 4             NaN  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648      8258.0   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649      8264.0    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650      8279.0   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651      8296.0   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652      8321.0   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 9          1318.0  12/31/2015 0:00      1/3/1954        8/28/1989
# 19         1319.0  12/31/2015 0:00      1/3/1957        8/28/1989
# 29         1320.0  12/31/2015 0:00      1/2/1955        8/28/1989
# 39         1321.0  12/31/2015 0:00      1/2/1959        8/28/1989
# 49         1322.0  12/31/2015 0:00      1/9/1958        8/31/1989
# ...           ...              ...           ...              ...
# 49648      8258.0   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649      8264.0    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650      8279.0   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651      8296.0   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652      8321.0   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 9                1/1/1900   61                 26    Vancouver
# ...

# %%
df= df.reset_index(drop = True)

# %%
df
# Out:
#       EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0         1318.0  12/31/2015 0:00      1/3/1954        8/28/1989
# 1         1319.0  12/31/2015 0:00      1/3/1957        8/28/1989
# 2         1320.0  12/31/2015 0:00      1/2/1955        8/28/1989
# 3         1321.0  12/31/2015 0:00      1/2/1959        8/28/1989
# 4         1322.0  12/31/2015 0:00      1/9/1958        8/31/1989
# ...          ...              ...           ...              ...
# 6279      8258.0   12/1/2015 0:00     5/28/1994        8/19/2013
# 6280      8264.0    8/1/2013 0:00     6/13/1994        8/27/2013
# 6281      8279.0   12/1/2015 0:00     7/18/1994        9/15/2013
# 6282      8296.0   12/1/2013 0:00      9/2/1994        10/9/2013
# 6283      8321.0   12/1/2014 0:00    11/28/1994       11/24/2013
#
#      terminationdate_key  age  length_of_service    city_name  \
# 0               1/1/1900   61                 26    Vancouver
# ...

# %%
df.columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
for col in ['recorddate_key', 'birthdate_key', 'orighiredate_key',
       'terminationdate_key']:
    df[col] = pd.to_datetime(df[col])

# %%
df
# Out:
#       EmployeeID recorddate_key birthdate_key orighiredate_key  \
# 0         1318.0     2015-12-31    1954-01-03       1989-08-28
# 1         1319.0     2015-12-31    1957-01-03       1989-08-28
# 2         1320.0     2015-12-31    1955-01-02       1989-08-28
# 3         1321.0     2015-12-31    1959-01-02       1989-08-28
# 4         1322.0     2015-12-31    1958-01-09       1989-08-31
# ...          ...            ...           ...              ...
# 6279      8258.0     2015-12-01    1994-05-28       2013-08-19
# 6280      8264.0     2013-08-01    1994-06-13       2013-08-27
# 6281      8279.0     2015-12-01    1994-07-18       2013-09-15
# 6282      8296.0     2013-12-01    1994-09-02       2013-10-09
# 6283      8321.0     2014-12-01    1994-11-28       2013-11-24
#
#      terminationdate_key  age  length_of_service    city_name  \
# 0             1900-01-01   61                 26    Vancouver
# 1             1900-01-01   58                 26    Vancouver
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6284 entries, 0 to 6283
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           6284 non-null   float64
#  1   recorddate_key       6284 non-null   datetime64[ns]
#  2   birthdate_key        6284 non-null   datetime64[ns]
#  3   orighiredate_key     6284 non-null   datetime64[ns]
#  4   terminationdate_key  6284 non-null   datetime64[ns]
#  5   age                  6284 non-null   int64
#  6   length_of_service    6284 non-null   int64
#  7   city_name            6284 non-null   object
#  8   department_name      6284 non-null   object
#  9   job_title            6284 non-null   object
#  10  store_name           6284 non-null   int64
#  11  gender_short         6284 non-null   object
#  12  gender_full          6284 non-null   object
#  13  termreason_desc      6284 non-null   object
# ...

# %%
d={'EmployeeID':'id',
   'recorddate_key':'record_date',
   'birthdate_key':'DOB', 
   'orighiredate_key':'hiredate',
   'terminationdate_key':'term_date',
   'length_of_service':'experience',
   'city_name':'city',
   'department_name':'dname',
   'job_title':'job',
   'gender_full':'gender',
   'store_name':'store',
   'termreason_desc':'term_reason',
   'termtype_desc':'term_type',
   'STATUS_YEAR':'status_year',
   'STATUS':'status',
   'BUSINESS_UNIT':'business_unit'
   }

df=df.rename(columns=d)

# %%
df.columns
# Out:
# Index(['id', 'record_date', 'DOB', 'hiredate', 'term_date', 'age',
#        'experience', 'city', 'dname', 'job', 'store', 'gender_short', 'gender',
#        'term_reason', 'term_type', 'status_year', 'status', 'business_unit'],
#       dtype='object')

# %% [markdown]
# <h2>4. Handle the invalid dtypes</h2>

# %%
d={
    'id':int
}
df=df.astype(d)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6284 entries, 0 to 6283
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             6284 non-null   int64
#  1   record_date    6284 non-null   datetime64[ns]
#  2   DOB            6284 non-null   datetime64[ns]
#  3   hiredate       6284 non-null   datetime64[ns]
#  4   term_date      6284 non-null   datetime64[ns]
#  5   age            6284 non-null   int64
#  6   experience     6284 non-null   int64
#  7   city           6284 non-null   object
#  8   dname          6284 non-null   object
#  9   job            6284 non-null   object
#  10  store          6284 non-null   int64
#  11  gender_short   6284 non-null   object
#  12  gender         6284 non-null   object
#  13  term_reason    6284 non-null   object
#  14  term_type      6284 non-null   object
#  15  status_year    6284 non-null   int64
#  16  status         6284 non-null   object
# ...

# %% [markdown]
# <h2>3. Drop the column ('gender_short' )</h2>

# %%
# df = df.drop(columns=['store','gender_short'])
df = df.drop(['store','gender_short'],axis=1 )

# %%
df.columns
# Out:
# Index(['id', 'record_date', 'DOB', 'hiredate', 'term_date', 'age',
#        'experience', 'city', 'dname', 'job', 'gender', 'term_reason',
#        'term_type', 'status_year', 'status', 'business_unit'],
#       dtype='object')

# %%
for col in ['status', 'business_unit']:
    df[col]= df[col].str.title()

# %%
df.head(2)
# Out:
#      id record_date        DOB   hiredate  term_date  age  experience  \
# 0  1318  2015-12-31 1954-01-03 1989-08-28 1900-01-01   61          26
# 1  1319  2015-12-31 1957-01-03 1989-08-28 1900-01-01   58          26
#
#         city      dname        job  gender     term_reason       term_type  \
# 0  Vancouver  Executive        CEO    Male  Not Applicable  Not Applicable
# 1  Vancouver  Executive  VP Stores  Female  Not Applicable  Not Applicable
#
#    status_year  status business_unit
# 0         2015  Active    Headoffice
# 1         2015  Active    Headoffice

# %%
r_date=df.query('status=="Active"')['record_date']
df.loc[df['status']=='Active','term_date']=r_date

# %%
df.head(2)
# Out:
#      id record_date        DOB   hiredate  term_date  age  experience  \
# 0  1318  2015-12-31 1954-01-03 1989-08-28 2015-12-31   61          26
# 1  1319  2015-12-31 1957-01-03 1989-08-28 2015-12-31   58          26
#
#         city      dname        job  gender     term_reason       term_type  \
# 0  Vancouver  Executive        CEO    Male  Not Applicable  Not Applicable
# 1  Vancouver  Executive  VP Stores  Female  Not Applicable  Not Applicable
#
#    status_year  status business_unit
# 0         2015  Active    Headoffice
# 1         2015  Active    Headoffice

# %%
df['experience'].min()
# Out:
# np.int64(0)

# %%
df['experience'].max()
# Out:
# np.int64(26)

# %% [markdown]
# range of experience is from 0 to 26

# %%
df['exp_level']=pd.cut(df['experience'],bins=[0,2,10,26],labels=['Junior','Mid-senior','Senior'],include_lowest=True)

# %%
df
# Out:
#         id record_date        DOB   hiredate  term_date  age  experience  \
# 0     1318  2015-12-31 1954-01-03 1989-08-28 2015-12-31   61          26
# 1     1319  2015-12-31 1957-01-03 1989-08-28 2015-12-31   58          26
# 2     1320  2015-12-31 1955-01-02 1989-08-28 2015-12-31   60          26
# 3     1321  2015-12-31 1959-01-02 1989-08-28 2015-12-31   56          26
# 4     1322  2015-12-31 1958-01-09 1989-08-31 2015-12-31   57          26
# ...    ...         ...        ...        ...        ...  ...         ...
# 6279  8258  2015-12-01 1994-05-28 2013-08-19 2015-12-30   21           2
# 6280  8264  2013-08-01 1994-06-13 2013-08-27 2013-08-30   19           0
# 6281  8279  2015-12-01 1994-07-18 2013-09-15 2015-12-30   21           2
# 6282  8296  2013-12-01 1994-09-02 2013-10-09 2013-12-31   19           0
# 6283  8321  2014-12-01 1994-11-28 2013-11-24 2014-12-30   20           1
#
#              city             dname                 job  gender  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'record_date', 'DOB', 'hiredate', 'term_date', 'age',
#        'experience', 'city', 'dname', 'job', 'gender', 'term_reason',
#        'term_type', 'status_year', 'status', 'business_unit', 'exp_level'],
#       dtype='object')

# %%
list=['id','DOB','age','gender','hiredate','dname','job','city','experience','exp_level','business_unit','status','term_date','term_reason','term_type','record_date','status_year']

# %%
df=df[list]

# %%
df
# Out:
#         id        DOB  age  gender   hiredate             dname  \
# 0     1318 1954-01-03   61    Male 1989-08-28         Executive
# 1     1319 1957-01-03   58  Female 1989-08-28         Executive
# 2     1320 1955-01-02   60  Female 1989-08-28         Executive
# 3     1321 1959-01-02   56    Male 1989-08-28         Executive
# 4     1322 1958-01-09   57    Male 1989-08-31         Executive
# ...    ...        ...  ...     ...        ...               ...
# 6279  8258 1994-05-28   21    Male 2013-08-19             Dairy
# 6280  8264 1994-06-13   19  Female 2013-08-27  Customer Service
# 6281  8279 1994-07-18   21  Female 2013-09-15  Customer Service
# 6282  8296 1994-09-02   19  Female 2013-10-09  Customer Service
# 6283  8321 1994-11-28   20  Female 2013-11-24  Customer Service
#
#                      job         city  experience exp_level business_unit  \
# 0                    CEO    Vancouver          26    Senior    Headoffice
# ...

# %%
# df['job'].str.split(',').str[0].unique()

# %% [markdown]
# <h3>apply(function, axis)</h3>

# %%
def f1(d):
    return d['job'].split(',')[0]

df['job']=df.apply(f1,axis=1)

# %% [markdown]
# # Analysis

# %% [markdown]
# <h3 style="color:orange">1. how many employees data is present</h3>

# %%
len(df)
# Out:
# 6284

# %% [markdown]
# <h3 style="color:orange">2. how many employees left the job</h3>

# %%
len(df.loc[df['status']=='Terminated'])
# Out:
# 1485

# %% [markdown]
# <h3 style="color:orange">3. how many employees are currently working</h3>

# %%
len(df.loc[df['status']=='Active'])
# Out:
# 4799

# %% [markdown]
# <h3 style="color:orange">4. how many employees are working as CEO</h3>

# %%
len(df.loc[df['job']=='CEO'])
# Out:
# 1

# %% [markdown]
# <h3 style="color:orange">5. how many employees are having more than 10 years of experience</h3>

# %%
len(df.loc[df['experience'] > 10,'id'])
# Out:
# 3825

# %%
df
# Out:
#         id        DOB  age  gender   hiredate             dname  \
# 0     1318 1954-01-03   61    Male 1989-08-28         Executive
# 1     1319 1957-01-03   58  Female 1989-08-28         Executive
# 2     1320 1955-01-02   60  Female 1989-08-28         Executive
# 3     1321 1959-01-02   56    Male 1989-08-28         Executive
# 4     1322 1958-01-09   57    Male 1989-08-31         Executive
# ...    ...        ...  ...     ...        ...               ...
# 6279  8258 1994-05-28   21    Male 2013-08-19             Dairy
# 6280  8264 1994-06-13   19  Female 2013-08-27  Customer Service
# 6281  8279 1994-07-18   21  Female 2013-09-15  Customer Service
# 6282  8296 1994-09-02   19  Female 2013-10-09  Customer Service
# 6283  8321 1994-11-28   20  Female 2013-11-24  Customer Service
#
#                      job         city  experience exp_level business_unit  \
# 0                    CEO    Vancouver          26    Senior    Headoffice
# ...

# %% [markdown]
# <h3 style="color:orange">6. get the unique record_year</h3>

# %%
df['record_date'].unique()
# Out:
# <DatetimeArray>
# ['2015-12-31 00:00:00', '2009-02-01 00:00:00', '2014-02-01 00:00:00',
#  '2014-03-01 00:00:00', '2009-03-01 00:00:00', '2012-09-01 00:00:00',
#  '2014-04-01 00:00:00', '2009-04-01 00:00:00', '2009-05-01 00:00:00',
#  '2014-05-01 00:00:00',
#  ...
#  '2013-03-01 00:00:00', '2013-04-01 00:00:00', '2013-05-01 00:00:00',
#  '2013-06-01 00:00:00', '2013-07-01 00:00:00', '2013-08-01 00:00:00',
#  '2013-09-01 00:00:00', '2013-11-01 00:00:00', '2013-12-01 00:00:00',
#  '2014-01-01 00:00:00']
# Length: 121, dtype: datetime64[ns]

# %% [markdown]
# <h3 style="color:orange">7. gender wise no_of_emp</h3>

# %%
df.groupby('gender').agg({'id':'count'})
# Out:
#           id
# gender
# Female  3278
# Male    3006

# %% [markdown]
# <h3 style="color:orange">8. gender wise no_of active employees</h3>

# %%
df[df['status'] == 'Active'].groupby('gender')['id'].count()
# Out:
# gender
# Female    2363
# Male      2436
# Name: id, dtype: int64

# %% [markdown]
# <h3 style="color:orange">9. job wise highest experience</h3>

# %%
df.groupby('job').agg({'experience':'max'})
# Out:
#                             experience
# job
# Accounting Clerk                    25
# Accounts Payable Clerk              24
# Accounts Receiveable Clerk          24
# Auditor                             24
# Baker                               24
# Bakery Manager                      25
# Benefits Admin                      24
# CEO                                 26
# CHief Information Officer           26
# Cashier                             21
# Compensation Analyst                24
# Corporate Lawyer                    24
# Customer Service Manager            25
# Dairy Manager                       24
# Dairy Person                        25
# Director                            26
# Exec Assistant                      26
# HRIS Analyst                        24
# Investment Analyst                  25
# Labor Relations Analyst             24
# Legal Counsel                       26
# Meat Cutter                         25
# Meats Manager                       26
# ...

# %% [markdown]
# <h3 style="color:orange">10. job wise no_of_emp</h3>

# %%
print(df['job'].value_counts())

or 

df.groupby('job')['id'].count().sort_values(ascending=False)
# Out:
#   Cell In[752], line 3
#     or
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# <h3 style="color:orange">11. job in which more employees are present</h3>

# %% [markdown]
# <h3 style="color:orange">12. job in which more employees are currently working</h3>

# %% [markdown]
# <h3 style="color:orange">13. job in which more employees left the job</h3>

# %% [markdown]
# <h3 style="color:orange">14. gender wise highest experience</h3>

# %% [markdown]
# <h3 style="color:orange">15. no_of_emp in each term_type</h3>

# %% [markdown]
# <h3 style="color:orange">16. no_of_emp in each term_reason</h3>

# %% [markdown]
# <h3 style="color:orange">17. year wise no_of hiring</h3>

# %% [markdown]
# <h3 style="color:orange">18. top two date on which more hiring happened</h3>

# %% [markdown]
# <h3 style="color:orange">19. get the year wise no_of_hirings </h3>

# %% [markdown]
# <h3 style="color:orange">20. get the year wise no_of_attrition</h3>

# %% [markdown]
# <h3 style="color:orange">21. get the year wise no_of_retention </h3>

# %% [markdown]
# <h3 style="color:orange">total number of record in a particular column. </h3>

# %%
df['id'].count()
# Out:
# np.int64(6284)

# %%
df.shape[0]    # df.shape ====> (no_of_rows,no_of_cols)
# Out:
# 6284

# %%
len(df)
# Out:
# 6284

# %% [markdown]
# <h3 style="color:orange">get the unique value from term reason. </h3>

# %%
print(df['term_reason'].unique())
# Out:
# ['Not Applicable' 'Retirement' 'Resignaton' 'Layoff']

# %%
df['term_reason'].nunique()
# Out:
# 4

# %% [markdown]
# <h3 style="color:orange">find the no of unique in gender.job,dname,city,business_unit</h3>

# %%
lst=['gender','job','dname','city','business_unit']
df[lst].nunique()
# Out:
# gender            2
# job              34
# dname            21
# city             40
# business_unit     2
# dtype: int64

# %% [markdown]
# <h3 style="color:orange">get the records of (0,25,700,500)</h3>

# %%
lst=[0,25,700,500]
df.loc[lst]
# Out:
#        id        DOB  age  gender   hiredate      dname           job  \
# 0    1318 1954-01-03   61    Male 1989-08-28  Executive           CEO
# 25   1721 1951-02-23   64    Male 1990-10-15      Meats   Meat Cutter
# 700  2857 1957-05-30   58  Female 1994-02-04     Bakery         Baker
# 500  2530 1955-10-21   60  Female 1993-03-31      Dairy  Dairy Person
#
#           city  experience exp_level business_unit  status  term_date  \
# 0    Vancouver          26    Senior    Headoffice  Active 2015-12-31
# 25   Cranbrook          25    Senior        Stores  Active 2015-12-31
# 700    Burnaby          21    Senior        Stores  Active 2015-12-31
# 500  Vancouver          22    Senior        Stores  Active 2015-12-31
#
#         term_reason       term_type record_date  status_year
# 0    Not Applicable  Not Applicable  2015-12-31         2015
# 25   Not Applicable  Not Applicable  2015-12-31         2015
# 700  Not Applicable  Not Applicable  2015-12-31         2015
# ...

# %% [markdown]
# <h3 style="color:orange">get the job of (0,25,700,500)</h3>

# %%
df.loc[[0,25,700,500],'job']
# Out:
# 0               CEO
# 25      Meat Cutter
# 700           Baker
# 500    Dairy Person
# Name: job, dtype: object

# %% [markdown]
# <h3 style="color:orange"></h3>

# %% [markdown]
# <h3 style="color:orange">get the job of (0,25,700,500) in ascending order of job</h3>

# %%
df.loc[[0,25,700,500],'job'].sort_values(ascending=True)
# Out:
# 700           Baker
# 0               CEO
# 500    Dairy Person
# 25      Meat Cutter
# Name: job, dtype: object

# %% [markdown]
# <h3 style="color:orange">get the job of (0,25,700,500) in decending order of job (values)</h3>

# %%
df.loc[[0,25,700,500],'job'].sort_values(ascending=False)
# Out:
# 25      Meat Cutter
# 500    Dairy Person
# 0               CEO
# 700           Baker
# Name: job, dtype: object

# %% [markdown]
# <h3 style="color:orange">get the job of (0,25,700,500) in ascending order of job (index)</h3>

# %%
df.loc[[0,25,700,500],'job'].sort_index(ascending=True)
# Out:
# 0               CEO
# 25      Meat Cutter
# 500    Dairy Person
# 700           Baker
# Name: job, dtype: object

# %% [markdown]
# <h3 style="color:orange">get the job of (0,25,700,500) in decending order of job (index)</h3>

# %%
df.loc[[0,25,700,500],'job'].sort_index(ascending=False)
# Out:
# 700           Baker
# 500    Dairy Person
# 25      Meat Cutter
# 0               CEO
# Name: job, dtype: object

# %% [markdown]
# <h3 style="color:orange"></h3>

# %% [markdown]
# <h3 style="color:orange">Get the 'Retirement' employee job and experience</h3>

# %%
df.loc[df['term_reason']=='Retirement',['job','experience']]
# Out:
#                 job  experience
# 4799       Director          19
# 4800  Store Manager          24
# 4801  Store Manager          19
# 4802       Director          19
# 4803  Store Manager          24
# ...             ...         ...
# 5819  Produce Clerk           8
# 5820  Produce Clerk           8
# 5821  Produce Clerk           8
# 5822          Baker          13
# 5824    Meat Cutter           8
#
# [885 rows x 2 columns]

# %%
df.query("term_reason=='Retirement'")[['job','experience']]
# Out:
#                 job  experience
# 4799       Director          19
# 4800  Store Manager          24
# 4801  Store Manager          19
# 4802       Director          19
# 4803  Store Manager          24
# ...             ...         ...
# 5819  Produce Clerk           8
# 5820  Produce Clerk           8
# 5821  Produce Clerk           8
# 5822          Baker          13
# 5824    Meat Cutter           8
#
# [885 rows x 2 columns]

# %% [markdown]
# <h3 style="color:orange">Get the 'Retirement' employee job and experience and sort it according to desc order of experience</h3>

# %%
df.query("term_reason=='Retirement'")[['job','experience']].sort_values(by='experience',ascending=False)
# Out:
#                            job  experience
# 4988  Customer Service Manager          25
# 5020              Dairy Person          25
# 4965          Accounting Clerk          25
# 5019             Meats Manager          25
# 5018   Processed Foods Manager          25
# ...                        ...         ...
# 5781             Produce Clerk           8
# 5784               Meat Cutter           8
# 5785             Produce Clerk           8
# 5787                     Baker           8
# 5824               Meat Cutter           8
#
# [885 rows x 2 columns]

# %% [markdown]
# <h3 style="color:orange">Get the 'Retirement' employee job and experience and sort it according to desc order of experience,and ascending order of job</h3>

# %%
df.query("term_reason=='Retirement'")[['job','experience']].sort_values(by=['experience','job'],ascending=[False,True])
# Out:
#                    job  experience
# 4951  Accounting Clerk          25
# 4955  Accounting Clerk          25
# 4956  Accounting Clerk          25
# 4965  Accounting Clerk          25
# 4967  Accounting Clerk          25
# ...                ...         ...
# 5805     Produce Clerk           8
# 5808     Produce Clerk           8
# 5819     Produce Clerk           8
# 5820     Produce Clerk           8
# 5821     Produce Clerk           8
#
# [885 rows x 2 columns]

# %% [markdown]
# <h3 style="color:orange">Get the retired male details</h3>

# %%
df.query("term_reason=='Retirement' and gender=='Male'")
# Out:
#         id        DOB  age gender   hiredate             dname            job  \
# 4799  1338 1949-02-16   60   Male 1989-09-20          Training       Director
# 4801  1340 1949-02-19   60   Male 1989-09-22  Store Management  Store Manager
# 4802  1341 1949-02-21   60   Male 1989-09-23   Labor Relations       Director
# 4806  1347 1949-03-04   60   Male 1989-09-29             Meats  Meats Manager
# 4807  1351 1949-03-09   60   Male 1989-10-02      Compensation       Director
# ...    ...        ...  ...    ...        ...               ...            ...
# 5813  5084 1948-12-02   60   Male 2000-06-08             Meats    Meat Cutter
# 5819  5098 1948-12-20   60   Male 2000-06-26           Produce  Produce Clerk
# 5820  5099 1948-12-21   60   Male 2000-06-27           Produce  Produce Clerk
# 5821  5104 1948-12-23   60   Male 2000-06-29           Produce  Produce Clerk
# 5824  5112 1948-12-30   60   Male 2000-07-06             Meats    Meat Cutter
#
# ...

# %%
df.loc[(df['term_reason']=='Retirement') & (df['gender']=='Male')]
# & ------>  (logical AND)
# ! ------>  (logical OR)
# Out:
#         id        DOB  age gender   hiredate             dname            job  \
# 4799  1338 1949-02-16   60   Male 1989-09-20          Training       Director
# 4801  1340 1949-02-19   60   Male 1989-09-22  Store Management  Store Manager
# 4802  1341 1949-02-21   60   Male 1989-09-23   Labor Relations       Director
# 4806  1347 1949-03-04   60   Male 1989-09-29             Meats  Meats Manager
# 4807  1351 1949-03-09   60   Male 1989-10-02      Compensation       Director
# ...    ...        ...  ...    ...        ...               ...            ...
# 5813  5084 1948-12-02   60   Male 2000-06-08             Meats    Meat Cutter
# 5819  5098 1948-12-20   60   Male 2000-06-26           Produce  Produce Clerk
# 5820  5099 1948-12-21   60   Male 2000-06-27           Produce  Produce Clerk
# 5821  5104 1948-12-23   60   Male 2000-06-29           Produce  Produce Clerk
# 5824  5112 1948-12-30   60   Male 2000-07-06             Meats    Meat Cutter
#
# ...

# %% [markdown]
# <h3 style="color:orange">Get the average age</h3>

# %%
print(df['age'].mean().round(2))

# or

print(round(df['age'].mean(),2))
# Out:
# 44.74
# 44.74

# %% [markdown]
# <h3 style="color:orange">Get The heighest and lowest experience</h3>

# %%
print(df['experience'].max())
print(df['experience'].min())
# Out:
# 26
# 0

# %% [markdown]
# aggregation function ----> agg({col:agg,col:agg},{exp:[max,min],sal:sum})

# %%
df.agg({'experience':['max','min']})
# Out:
#      experience
# max          26
# min           0

# %% [markdown]
# <h3 style="color:orange">Get the no of employess in each term_type</h3>

# %%
g = df.groupby(by='term_type')
g['term_type'].count()

# or

print(df.groupby(by='term_type')['term_type'].count())   #index is in ascending order

# The term_type will become index
# agg_values will be column
# Out:
# term_type
# Involuntary        215
# Not Applicable    4799
# Voluntary         1270
# Name: term_type, dtype: int64

# %% [markdown]
# grouping and counting both can be applied in one step using value_count()

# %%
df['term_type'].value_counts(ascending=True)
# Out:
# term_type
# Involuntary        215
# Voluntary         1270
# Not Applicable    4799
# Name: count, dtype: int64

# %% [markdown]
# <h3 style="color:orange">Get the least emp_cnt in each term_type</h3>

# %%
print(df['term_type'].value_counts().min())
# Out:
# 215

# %% [markdown]
# <h3 style="color:orange">Get the term_type in which least emp are present</h3>

# %%
df['term_type'].value_counts().idxmin()

# idx ====>index
# Out:
# 'Involuntary'

# %% [markdown]
# <h3 style="color:orange">Get the term_type in which highest emp are present</h3>

# %%
df['term_type'].value_counts().idxmax()

# idx ====>index
# Out:
# 'Not Applicable'

# %% [markdown]
# <h3 style="color:orange">Get the no of employeed and average age in each dname</h3>

# %%
df.groupby('dname').agg({'id':'count','age':'mean'}).round(2)
# Out:
#                           id    age
# dname
# Accounting                 6  65.00
# Accounts Payable           4  63.75
# Accounts Receiveable       5  63.00
# Audit                      4  61.25
# Bakery                   898  45.78
# Compensation               4  61.25
# Customer Service        1190  30.81
# Dairy                   1033  39.88
# Employee Records           6  63.33
# Executive                 10  56.90
# HR Technology              9  63.00
# Information Technology     5  60.00
# Investment                 4  61.25
# Labor Relations            6  61.67
# Legal                      3  61.67
# Meats                   1252  57.50
# Processed Foods          736  35.77
# Produce                 1060  53.55
# Recruitment                9  62.56
# Store Management          35  61.97
# Training                   5  62.00

# %% [markdown]
# <h3 style="color:orange">Get the no of employeed and average age in each status year ,business_unit</h3>

# %%
df.groupby(['status_year','business_unit']).agg({'id':'count','age':'mean'}).round(2)
# Out:
#                              id    age
# status_year business_unit
# 2006        Stores          134  60.00
# 2007        Headoffice        1  57.00
#             Stores          161  59.20
# 2008        Stores          164  58.42
# 2009        Headoffice       23  60.00
#             Stores          119  59.11
# 2010        Headoffice        9  60.00
#             Stores          114  55.18
# 2011        Stores          110  43.06
# 2012        Stores          130  44.15
# 2013        Stores          105  47.95
# 2014        Headoffice       24  65.00
#             Stores          229  37.86
# 2015        Headoffice       23  60.96
#             Stores         4938  42.84

# %% [markdown]
# <h3 style="color:orange">Get the job in which more than 100 employees are present </h3>

# %%
g= df['job'].value_counts()
a=g[g>100]
a.index

# or

g[df['job'].value_counts() >100].index
# Out:
# Index(['Meat Cutter', 'Cashier', 'Dairy Person', 'Produce Clerk', 'Baker',
#        'Shelf Stocker'],
#       dtype='object', name='job')

# %% [markdown]
# <h3 style="color:orange">Get the statistical description for all numerical columns</h3>

# %%
lst=['age','experience']
df[lst].describe()


# except alphabetical data everything is included in describe()
# Out:
#                age   experience
# count  6284.000000  6284.000000
# mean     44.742998    12.836410
# std      14.134458     6.747744
# min      19.000000     0.000000
# 25%      32.000000     7.000000
# 50%      45.000000    13.000000
# 75%      58.000000    19.000000
# max      65.000000    26.000000

# %% [markdown]
# <h3 style="color:orange">Get the highest age in each status_year</h3>

# %%
df.groupby(by='status_year')['age'].max()
# Out:
# status_year
# 2006    65
# 2007    65
# 2008    65
# 2009    65
# 2010    65
# 2011    65
# 2012    65
# 2013    65
# 2014    65
# 2015    65
# Name: age, dtype: int64

# %% [markdown]
# <h1 style="color:Red">Visualization</h1>

# %% [markdown]
# <ol>
# <li>Univariant plots (1 column)</li>
# <li>Bivariant plots (2 column)</li>
# <li>Multivariant plots (more than 2 column)</li>
# </ol>

# %% [markdown]
# <h1 style="color:Red">Univariant plots (1 column)</h1>

# %% [markdown]
# <h3 style="color:orange">How many employees are there in each status category?</h3>

# %%
# Now if i want to customize the graph  ---->use matplotlib

plt.figure(figsize=(3,2)) #(width,height)
sns.countplot(data=df,x='status',hue='status')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul><li>more Active employees present compare than Terminated employees</li></ul></h3>

# %%
# Now if i want to customize the graph  ---->use matplotlib

plt.figure(figsize=(2,5)) #(width,height)
sns.countplot(data=df,x='gender',hue='status')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
# To avoid extra information

# plt.figure(figsize=(1,2)) #(width,height)
sns.countplot(data=df,x='gender',hue='status')
plt.show()

# %%
# To avoid extra information

plt.figure(figsize=(5,2)) #(width,height)
sns.countplot(data=df,x='gender',hue='status')
plt.title('Status wise count')
plt.show()

# %% [markdown]
# <h3 style="color:orange">How many active and terminated employees are there in each experience level?</h3>

# %%
# Now if i want to customize the graph  ---->use matplotlib

plt.figure(figsize=(6,2)) #(width,height)
sns.countplot(data=df,x='exp_level',hue='status')
plt.title('Experience level wise Active and Terminated emps')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul><li>Active employees are more in mid-senior and senior level employees </li>
# <li>Senior emp are more than mid-senior emp </li></ul></h3>

# %% [markdown]
# <h1 style="color:red">Pie plot</h1>

# %% [markdown]
# <h3 style="color:orange">Draw a pie chart from the attrition dataset that shows the proportion of different termination types among employees.</h3>

# %%
df['term_type'].value_counts()
idx = df['term_type'].value_counts().index
val = df['term_type'].value_counts().values
print(idx,val)
# Out:
# Index(['Not Applicable', 'Voluntary', 'Involuntary'], dtype='object', name='term_type') [4799 1270  215]

# %%
plt.figure(figsize=(4,4))
# plt.pie(x=val)
# plt.pie(x=val,labels=idx)
# plt.pie(x=val,labels=idx,autopct='%.3f')
plt.pie(x=val,labels=idx,autopct='%.3f%%')
plt.title('proportion of term_type')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul><li>Active employees are more than terminated employees </li>
# <li>voluntary terminations are more than involuntary</li></ul></h3>

# %% [markdown]
# <h1 style="color:red">KDE plot</h1>

# %% [markdown]
# <h3 style="color:orange">Visualize the probability density of employee ages usinf KDE plot<br>
# <span style="color:red">OR</span><br>
# Plot a smooth curve to understand how employee ages are distributed.</h3>

# %%
plt.figure(figsize=(5,2))
sns.kdeplot(data=df,x='age')
plt.grid()
plt.xticks(range(10,75,5))
plt.title('Age distribution')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation:
# <ul>
# <li>More data points (ages) are concentrated around </li>
# </ul></h3>

# %% [markdown]
# <h1 style="color:red">Hist plot</h1>

# %% [markdown]
# <h3 style="color:orange">Visualize the probability density of employee ages usinf Hist plot<br>
# <span style="color:red">OR</span><br>
# Plot a histogram to understand how employee ages are distributed.</h3>

# %%
plt.figure(figsize=(5,2))
sns.histplot(data=df,x='age')
plt.xticks(range(10,75,5))
plt.title('Age distribution')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul><li>More data points (ages) are concentrated around </li>
# <li>Majority of ages lies in the range of 60 to 65</li></ul></h3>

# %% [markdown]
# <h1 style="color:Red">Bivariant plots (2 column)</h1>

# %% [markdown]
# <ol>
# <li>Bar plots</li>
# <li>Scatter plots </li>
# <li>Line plot</li>
# <li>Box plot</li>
# </ol>

# %% [markdown]
# <h1 style="color:Red">Bar plot</h1>

# %% [markdown]
# <h3 style="color:orange">Show the average experience for each gender.</h3>

# %%
plt.figure(figsize=(4,4))
# sns.barplot(data=df,x='gender',y='experience') ------->  #default estimator is mean
sns.barplot(data=df,x='gender',y='experience',estimator='mean')
plt.title('Average experience in each gender')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul><li></li>
# <li></li></ul></h3>

# %% [markdown]
# <h3 style="color:orange">Show the max experience of emp for each gender and status.</h3>

# %%
plt.figure(figsize=(8,3))
sns.barplot(data=df,x='gender',y='experience',estimator='max',hue='status')
plt.title('Genderwise average experience')
plt.legend(loc='upper right', fontsize=7,borderpad=1,edgecolor='black')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul><li></li>
# <li></li></ul></h3>

# %% [markdown]
# <h1 style="color:Red">Scatter plot</h1>

# %% [markdown]
# <h3 style="color:orange">Create a scatter plot to visualize the relationship between emp age and experience. </h3>

# %%
plt.figure(figsize=(6,2))
sns.scatterplot(data=df,x='age',y='experience')
plt.title('relationship between age and experience')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul><li>Age and experience have positive strong relation. </li>
# <li>As age increases, experience also increases</li></ul></h3>

# %% [markdown]
# <h3 style="color:orange">Create a scatter plot to visualize the relationship between emp age and experience for each status. </h3>

# %%
plt.figure(figsize=(6,2))
sns.scatterplot(data=df,x='age',y='experience',hue='status',hue_order=['Active','Terminated'])
plt.title('relationship between age and experience')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul><li>Age and experience have positive strong relation for terminated emp compare to active. </li>
# <li>As age increases, experience also increases</li></ul></h3>

# %% [markdown]
# <h1 style="color:Red">Line plot</h1>

# %% [markdown]
# <h3 style="color:orange">Visualize the trend of experience across different ages using line plot. </h3>

# %%
plt.figure(figsize=(6,2))
sns.lineplot(data=df,x='age',y='experience')
plt.title('Trend of age v/s experience')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul><li>Age and experience have positive strong relation. </li>
# <li>As age increases, experience also increases</li>
# <li>Few data points follows different pattern</li>
# <li>Senior emp also have less experience</li>
# </ul></h3>

# %% [markdown]
# <h1 style="color:Red">Box plot</h1>

# %% [markdown]
# <h3 style="color:orange">Use a box plot to find outliers in the age column. </h3>

# %%
plt.figure(figsize=(6,2))
sns.boxplot(data=df,x='age')
plt.title('Outliers in age colume')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul>
# <li>Age col has no outliers. </li>
# </ul></h3>

# %% [markdown]
# <h3 style="color:orange">Use a box plot to find outliers in the experience column. </h3>

# %%
plt.figure(figsize=(6,2))
sns.boxplot(data=df,x='experience')
plt.title('Outliers in experience colume')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul>
# <li>Experience col has no outliers. </li>
# </ul></h3>

# %% [markdown]
# <h3 style="color:orange">Use a box plot to find outliers in the experience and gender column. </h3>

# %%
plt.figure(figsize=(6,2))
sns.boxplot(data=df,x='experience',y='gender')
plt.title('Outliers in experience and gender colume')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul>
# <li>Experience and gender col has no outliers. </li>
# </ul></h3>

# %% [markdown]
# <h3 style="color:orange">Use a box plot to find outliers in the experience and gender column in each status. </h3>

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df,y='experience',x='gender',hue='status')
plt.title('Outliers in experience and gender column')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul>
# <li>Outliers are detected in the terminated female employees experience. </li>
# </ul></h3>

# %% [markdown]
# <h1 style="color:Red">Multivariant plots (more than 2 column)</h1>

# %% [markdown]
# <ol>
# <li>Heat Map</li>
# <li>Pair plot</li>
# </ol>

# %% [markdown]
# <h1 style="color:Red">HeatMap</h1>

# %% [markdown]
# <h3 style="color:orange">Use a heatmap. </h3>

# %%
c = df.corr(numeric_only=True)

# %%
sns.heatmap(c,annot=True,fmt='.3g')
# Out:
# <Axes: >

# %% [markdown]
# <h3 style='color:Skyblue'>Observation: <ul>
# <li>Age and experience are having 85% of positive strong relation. </li>
# </ul></h3>

# %% [markdown]
# <h1 style="color:Red">Pair plot</h1>

# %% [markdown]
# <h3 style="color:orange">Create a pairplot to visualize pairwise relationship between numerical features. </h3>

# %%
c = df.corr(numeric_only=True)
sns.pairplot(data=df)

# %%
c = df.corr(numeric_only=True)
sns.pairplot(df[['age','experience','status']])
